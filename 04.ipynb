# %%
문제 설명
1부터 N까지 번호가 하나씩 붙은 디렉토리 N개가 트리(tree) 형태를 이루고 있습니다. 디렉토리 간에 이동할 때는 
현재 디렉토리와 직접 연결된 하위 디렉토리로 이동하거나, 혹은 현재 디렉토리의 상위 디렉토리로 이동할 수 있습니다.

다음은 디렉토리 구조를 보인 예시입니다.

direct_1.png

예를 들어 위 예시에서 ②번 디렉토리의 하위 디렉토리는 ④, ⑤번 디렉토리 이며, 상위 디렉토리는 ①번 디렉토리입니다.
이때, ④번 디렉토리에서 출발해 ③번 디렉토리로 이동하려면 다음과 같이 이동하면 됩니다.

④번 디렉토리에서 출발 → 상위 디렉토리(②번)로 이동 → 상위 디렉토리(①번)로 이동 → 하위 디렉토리(③번)로 이동
따라서, 출발, 도착 디렉토리인 ③, ④번 디렉토리를 포함하여 총 디렉토리 4개를 방문합니다.

또 다른 예로 ⑤번 디렉토리에서 ①번 디렉토리로 이동하려면 상위 디렉토리로 두 번만 이동하면 되며,
총 디렉토리 3개를 방문합니다.

디렉토리 개수 N, 상위 - 하위 디렉토리 관계를 나타내는 배열 directory와
[출발 디렉토리 번호,도착 디렉토리 번호] 여럿을 원소로 담은 query가 solution 함수의 매개변수로 주어집니다. 
각 [출발 디렉토리 번호, 도착 디렉토리 번호]에 대해 방문하는 디렉토리 수를 순서대로 담은 배열을 return 하도록 
solution 함수를 완성해 주세요.

제한 사항
디렉토리 개수 N은 3 이상 100,000 이하인 자연수입니다.
directory는 디렉토리 관계를 나타내는 배열이며 길이는 N - 1입니다.
directory에 들어있는 숫자는 1 이상 N 이하인 자연수입니다.
directory의 원소는 [상위 디렉토리 번호, 하위 디렉토리 번호] 형식입니다.
예를 들어 [1, 2]는 2번 디렉토리가 1번 디렉토리의 하위 디렉토리 라는 의미입니다.
디렉토리의 관계가 중복해서 주어지지 않습니다.
올바른 디렉토리 관계만 입력으로 주어집니다.
입력으로 주어지는 디렉토리는 하나의 트리를 구성하며, 최상위 디렉토리도 정확히 1개입니다.
최상위 디렉토리를 제외한 모든 디렉토리의 상위 디렉토리는 정확히 1개입니다.
query는 길이가 1 이상 100,000 이하인 배열입니다.
query의 원소는 [출발 디렉토리 번호, 도착 디렉토리 번호] 형식입니다.
입출력 예시
N	directory	query	result
5	[ [1, 2], [1, 3], [2, 4], [2, 5] ]	[ [1, 5], [2, 5], [3, 5], [4, 5] ]	[3, 2, 4, 3]
4	[ [3, 2], [3, 1], [3, 4]]	[ [4, 2],[3, 1], [2, 2] ]	[3, 2, 1]
입출력 예시 설명
입출력 예 #1

direct_1.png

①번 디렉토리에서 ⑤번 디렉토리로 가려면 ① → ② → ⑤로 이동하면 되며 디렉토리 3개를 방문합니다.
②번 디렉토리에서 ⑤번 디렉토리로 가려면 ② → ⑤로 이동하면 되며 디렉토리 2개를 방문합니다.
③번 디렉토리에서 ⑤번 디렉토리로 가려면 ③ → ① → ② → ⑤로 이동하면 되며 디렉토리 4개를 방문합니다.
④번 디렉토리에서 ⑤번 디렉토리로 가려면 ④ → ② → ⑤로 이동하면 되며 디렉토리 3개를 방문합니다.
따라서 [3, 2, 4, 3]을 return 하면 됩니다.

입출력 예 #2

direct_3.png

④번 디렉토리에서 ②번 디렉토리로 가려면 ④ → ③ → ②로 이동하면 되며 디렉토리 3개를 방문합니다.
③번 디렉토리에서 ①번 디렉토리로 가려면 ③ → ①로 이동하면 되며 디렉토리 2개를 방문합니다.
②번 디렉토리에서 ②번 디렉토리로는 이동하지 않아도 되므로 디렉토리 1개를 방문합니다.
따라서 [3, 2, 1]을 return 하면 됩니다.
# Out:
#   File "<ipython-input-138-ad86d6187beb>", line 1
#     문제 설명
#         ^
# SyntaxError: invalid syntax

# %%
# 어디서 depth를 주고 받고 쌓을 지 모르겠다. 
# 올바른 경로에서만 depth를 +해주고 return해준것을 다시 받아서 늘리고 해야되는데....

#왜 같은 for문 단계에서 호출하는데 depth를 공유해서 쓰고있는 것인가? 이것을 막고 
# 한번의 탐색에서만 depth를 저장해가는 방법이 없나 ?

# %%
# 트리 공부를 안 했으니 트리구조 생각 안하고 재귀 적으로 풀어보겠다. 


def get_how_far_reach(N,directory,start_num_input,end_num_input,finish_flag,depth,got_value_flag,proof_endless_depth): # finish_flag 기본값 False
    # one_query      [1, 5]
    # start_num_input = 1
    # end_num_input = 5
    # directory     [ [1, 2], [1, 3], [2, 4], [2, 5] ]
    
    # 종료 조건을 어떻게 써야할지 모르겠다. 
    
    # 값을 찾았고 리턴해 주고 싶다면 ? 
    if finish_flag ==True and got_value_flag ==True:
        return depth
    
    # depth만 끝까지 탐색해서 탈출하고 싶다면 ?
    if finish_flag ==True:
        return
    
    # 함수가 한번 호출 될때마다 depth + 해주자.
    proof_endless_depth +=1
    print(f'proof_endless_depth: {proof_endless_depth}')
    
    finish_flag = False
    got_value_flag = False

    
    
    for index,value in enumerate(directory):
        
        start = value[0]
        end = value[1]
        
        
        print(f'start: {start},  start_num_input: {start_num_input} , end:{end}, end_num_input:{end_num_input}')
        
        if start == start_num_input: #함수 호출시 받은 start_num_inpu과 이 start가 같다면 
            
            start_num_next = end
            depth_temp = depth
            depth+=1
            
            
            if end == end_num_input:
                finish_flag = True
                got_value_flag = True
                
            
            if proof_endless_depth >= N:
                finish_flag = True
            
            
            # 최종 out이 빈값이 아니라면 거기에 depth담아서 리턴해 주겠다. 
            final_out = get_how_far_reach(N,directory,start_num_next,end_num_input,finish_flag,depth,got_value_flag,proof_endless_depth)
            
            if final_out:
                return final_out
            
            depth = depth_temp
                
        
        elif end == start_num_input: #함수 호출시 받은 start_num_inpu과 이 end 가 같다면
        
            start_num_next = start
            depth+=1
            
            if start == end_num_input:
                finish_flag = True
                got_value_flag = True

            
            if proof_endless_depth >= N:
                finish_flag = True
            
            final_out = get_how_far_reach(N,directory,start_num_next,end_num_input,finish_flag,depth,got_value_flag,proof_endless_depth)
            
            if final_out:
                return final_out
            
            depth-=1
    
    
    
    
            


def solution(N, directory,query):
    
    
    finish_flag = False
    got_value_flag = False
    
    
    for index,item in enumerate(query): #  [ [1, 5], [2, 5], [3, 5], [4, 5] ]


        
        start_num_input = item[0]
        end_num_input = item[1]
        depth = 0
        proof_endless_depth = 0
        
        result = get_how_far_reach(N,directory,start_num_input,end_num_input,finish_flag,depth,got_value_flag,proof_endless_depth)
        
        print(f'fin_depth:{result}')
        print(f'{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}')
    
    
    
    
    return

# %%
N = 5
directory = [ [1, 2], [1, 3], [2, 4], [2, 5] ]
query = [ [1, 5], [2, 5], [3, 5], [4, 5] ]
solution(N, directory,query)
# [3, 2, 4, 3]
# Out:
# proof_endless_depth: 1
# start: 1,  start_num_input: 1 , end:2, end_num_input:5
# proof_endless_depth: 2
# start: 1,  start_num_input: 2 , end:2, end_num_input:5
# proof_endless_depth: 3
# start: 1,  start_num_input: 1 , end:2, end_num_input:5
# proof_endless_depth: 4
# start: 1,  start_num_input: 2 , end:2, end_num_input:5
# proof_endless_depth: 5
# start: 1,  start_num_input: 1 , end:2, end_num_input:5
# start: 1,  start_num_input: 1 , end:3, end_num_input:5
# start: 2,  start_num_input: 1 , end:4, end_num_input:5
# start: 2,  start_num_input: 1 , end:5, end_num_input:5
# start: 1,  start_num_input: 2 , end:3, end_num_input:5
# start: 2,  start_num_input: 2 , end:4, end_num_input:5
# proof_endless_depth: 5
# start: 1,  start_num_input: 4 , end:2, end_num_input:5
# start: 1,  start_num_input: 4 , end:3, end_num_input:5
# start: 2,  start_num_input: 4 , end:4, end_num_input:5
# start: 2,  start_num_input: 4 , end:5, end_num_input:5
# ...

# %%
N = 4
directory = [ [3, 2], [3, 1], [3, 4]]
query = [ [4, 2],[3, 1], [2, 2] ]
solution(N, directory,query)
# [3, 2, 1]
# Out:
# proof_endless_depth: 1
# start: 3,  start_num_input: 4 , end:2, end_num_input:2
# start: 3,  start_num_input: 4 , end:1, end_num_input:2
# start: 3,  start_num_input: 4 , end:4, end_num_input:2
# proof_endless_depth: 2
# start: 3,  start_num_input: 3 , end:2, end_num_input:2
# fin_depth:2
# 000000000000000
# proof_endless_depth: 1
# start: 3,  start_num_input: 3 , end:2, end_num_input:1
# proof_endless_depth: 2
# start: 3,  start_num_input: 2 , end:2, end_num_input:1
# proof_endless_depth: 3
# start: 3,  start_num_input: 3 , end:2, end_num_input:1
# proof_endless_depth: 4
# start: 3,  start_num_input: 2 , end:2, end_num_input:1
# start: 3,  start_num_input: 2 , end:1, end_num_input:1
# start: 3,  start_num_input: 2 , end:4, end_num_input:1
# start: 3,  start_num_input: 3 , end:1, end_num_input:1
# fin_depth:3
# 111111111111111
# proof_endless_depth: 1
# start: 3,  start_num_input: 2 , end:2, end_num_input:2
# proof_endless_depth: 2
# ...

# %%
# 일시 저장 


# 트리 공부를 안 했으니 트리구조 생각 안하고 재귀 적으로 풀어보겠다. 


def get_how_far_reach(N,directory,start_num_input,end_num_input,finish_flag,depth,got_value_flag): # finish_flag 기본값 False
    # one_query      [1, 5]
    # start_num_input = 1
    # end_num_input = 5
    # directory     [ [1, 2], [1, 3], [2, 4], [2, 5] ]
    
    # 종료 조건을 어떻게 써야할지 모르겠다. 
    
    # 값을 찾았고 리턴해 주고 싶다면 ? 
    if finish_flag ==True and got_value_flag ==True:
        return depth
    
    # depth만 끝까지 탐색해서 탈출하고 싶다면 ? 
    

    
    finish_flag = False
    got_value_flag = False
    
    for index,value in enumerate(directory):
        
        start = value[0]
        end = value[1]
        
        
        print(f'start: {start},  start_num_input: {start_num_input} , end:{end}, end_num_input:{end_num_input}')
        if start == start_num_input: #만약 맨 위에서 받은 start_num과 이 start가 같다면 
            start_num_next = end
            depth = depth+1
            print(f'depth: {depth}')
            if(end == end_num_input):
                finish_flag = True
                got_value_flag = True
                real_depth  = depth
                
            # 제귀를 N번이상 하는 경우 그냥 탈출.
            if depth>=N:
                print(f'N: {N}')
                finish_flag = True

            get_how_far_reach(N,directory,start_num_next,end_num_input,finish_flag,depth,got_value_flag)
        
#         반대로 타고 올라가는 경우.
        elif end == start_num_input:
            start_num_next = start
            depth = depth+1
            print(f'depth: {depth}')
            if(start == end_num_input):
                got_value_flag = True
                finish_flag = True
                real_depth  = depth

            # 제귀를 N번이상 하는 경우 그냥 탈출.
            if depth>=N:
                print(f'N: {N}')
                finish_flag = True

            get_how_far_reach(N,directory,start_num_next,end_num_input,finish_flag,depth,got_value_flag)
            



def solution(N, directory,query):
    
    global depth
    global real_depth
    
    depth = 0
    
    finish_flag = False
    
    
    for index,item in enumerate(query): #  [ [1, 5], [2, 5], [3, 5], [4, 5] ]
        depth = 0
        proof_endless_depth = 0 
        
        start_num_input = item[0]
        end_num_input = item[1]
        
        result = get_how_far_reach(N,directory,start_num_input,end_num_input,finish_flag,depth,got_value_flag)
        
        print(f'fin_depth:{result}')
        print(f'{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}{index}')
    
    answer = []
    
    
    
    return answer
